# %% [markdown]
# # Introduction to Pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %% [markdown]
# ## Working with series

# %%
pd.Series([12,23,45,66,67])
# Out:
# 0    12
# 1    23
# 2    45
# 3    66
# 4    67
# dtype: int64

# %%
# ?pd.Series

# %%
pd.Series([23,4,54,5,4,55,4], index=['a', 'b','c','d','e','f','h'])
# Out:
# a    23
# b     4
# c    54
# d     5
# e     4
# f    55
# h     4
# dtype: int64

# %%
cars = {
    'car1':'kantanka',
    'car2':'BMW',
    'car3':'Bugati',
    'car4':'Toyota'
}

# %%
series1 = pd.Series(cars)

# %%
series1.dtype
# Out:
# dtype('O')

# %%
series1.index
# Out:
# Index(['car1', 'car2', 'car3', 'car4'], dtype='object')

# %%
series1.shape
# Out:
# (4,)

# %%
series1.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 4 entries, car1 to car4
# Series name: None
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      object
# dtypes: object(1)
# memory usage: 236.0+ bytes

# %% [markdown]
# ## Working with data frames

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
student = {
    'Names':['Godwin', 'cecil', 'Hannah', 'Jennefer', 'Phillis', 'Isaac', 'King'],
    'Age':[23,20,19,44,23,22, 22],
    'Location': ['Accra',"Kumasi",'Tarkwa','Ofankor','Ossino', 'Nkawkaw', 'Suhum']
}

# %%
student
# Out:
# {'Names': ['Godwin',
#   'cecil',
#   'Hannah',
#   'Jennefer',
#   'Phillis',
#   'Isaac',
#   'King'],
#  'Age': [23, 20, 19, 44, 23, 22, 22],
#  'Location': ['Accra',
#   'Kumasi',
#   'Tarkwa',
#   'Ofankor',
#   'Ossino',
#   'Nkawkaw',
#   'Suhum']}

# %%
student['Names']
# Out:
# ['Godwin', 'cecil', 'Hannah', 'Jennefer', 'Phillis', 'Isaac', 'King']

# %%
student['Age']
# Out:
# [23, 20, 19, 44, 23, 22, 22]

# %%
student["Location"]
# Out:
# ['Accra', 'Kumasi', 'Tarkwa', 'Ofankor', 'Ossino', 'Nkawkaw', 'Suhum']

# %%
listOfStudent = pd.DataFrame(student)

# %%
listOfStudent
# Out:
#       Names  Age Location
# 0    Godwin   23    Accra
# 1     cecil   20   Kumasi
# 2    Hannah   19   Tarkwa
# 3  Jennefer   44  Ofankor
# 4   Phillis   23   Ossino
# 5     Isaac   22  Nkawkaw
# 6      King   22    Suhum

# %%
    listOfStudent['Names']
# Out:
# 0      Godwin
# 1       cecil
# 2      Hannah
# 3    Jennefer
# 4     Phillis
# 5       Isaac
# 6        King
# Name: Names, dtype: object

# %%
listOfStudent[['Age','Names']]
# Out:
#    Age     Names
# 0   23    Godwin
# 1   20     cecil
# 2   19    Hannah
# 3   44  Jennefer
# 4   23   Phillis
# 5   22     Isaac
# 6   22      King

# %%
sales = pd.read_excel('pretech_eg.xlsx')

# %% [markdown]
# ## Viewing  data

# %%
sales
# Out:
#     Order Date Region          State  Category         Product  Quantity  \
# 0   2021-01-01   East  Massachusetts      Bars          Carrot        33
# 1   2021-01-08   East  Massachusetts  Crackers     Whole Wheat        87
# 2   2021-01-15   West          Texas   Cookies  Chocolate Chip        58
# 3   2021-01-22   East       New York   Cookies  Chocolate Chip        82
# 4   2021-01-29   East  Massachusetts   Cookies       Arrowroot        38
# ..         ...    ...            ...       ...             ...       ...
# 239 2025-08-01   East  Massachusetts   Cookies       Arrowroot        34
# 240 2025-08-08   East  Massachusetts   Cookies  Chocolate Chip       245
# 241 2025-08-15   East  Massachusetts  Crackers     Whole Wheat        30
# 242 2025-08-22   West          Texas      Bars            Bran        30
# 243 2025-08-29   West          Texas   Cookies  Oatmeal Raisin        44
#
#      Unit Price  Revenue
# 0           596    19668
# 1           255    22185
# ...

# %%
sales.head()
# Out:
#   Order Date Region          State  Category         Product  Quantity  \
# 0 2021-01-01   East  Massachusetts      Bars          Carrot        33
# 1 2021-01-08   East  Massachusetts  Crackers     Whole Wheat        87
# 2 2021-01-15   West          Texas   Cookies  Chocolate Chip        58
# 3 2021-01-22   East       New York   Cookies  Chocolate Chip        82
# 4 2021-01-29   East  Massachusetts   Cookies       Arrowroot        38
#
#    Unit Price  Revenue
# 0         596    19668
# 1         255    22185
# 2         367    21286
# 3         680    55760
# 4         317    12046

# %%
sales.head(10)
# Out:
#   Order Date Region          State  Category         Product  Quantity  \
# 0 2021-01-01   East  Massachusetts      Bars          Carrot        33
# 1 2021-01-08   East  Massachusetts  Crackers     Whole Wheat        87
# 2 2021-01-15   West          Texas   Cookies  Chocolate Chip        58
# 3 2021-01-22   East       New York   Cookies  Chocolate Chip        82
# 4 2021-01-29   East  Massachusetts   Cookies       Arrowroot        38
# 5 2021-02-05   East  Massachusetts      Bars          Carrot        54
# 6 2021-02-12   East  Massachusetts  Crackers     Whole Wheat       149
# 7 2021-02-19   West          Texas      Bars          Carrot        51
# 8 2021-02-26   East       New York      Bars          Carrot       100
# 9 2021-03-05   East       New York    Snacks    Potato Chips        28
#
#    Unit Price  Revenue
# 0         596    19668
# 1         255    22185
# 2         367    21286
# 3         680    55760
# 4         317    12046
# 5         561    30294
# ...

# %%
sales.tail()
# Out:
#     Order Date Region          State  Category         Product  Quantity  \
# 239 2025-08-01   East  Massachusetts   Cookies       Arrowroot        34
# 240 2025-08-08   East  Massachusetts   Cookies  Chocolate Chip       245
# 241 2025-08-15   East  Massachusetts  Crackers     Whole Wheat        30
# 242 2025-08-22   West          Texas      Bars            Bran        30
# 243 2025-08-29   West          Texas   Cookies  Oatmeal Raisin        44
#
#      Unit Price  Revenue
# 239         469    15946
# 240         401    98245
# 241         640    19200
# 242         621    18630
# 243         641    28204

# %%
sales.tail(10)
# Out:
#     Order Date Region          State  Category         Product  Quantity  \
# 234 2025-06-27   West          Texas      Bars            Bran        42
# 235 2025-07-04   West          Texas   Cookies  Oatmeal Raisin       100
# 236 2025-07-11   East       New York      Bars          Carrot        38
# 237 2025-07-18   East       New York  Crackers     Whole Wheat        25
# 238 2025-07-25   West     California   Cookies  Chocolate Chip        96
# 239 2025-08-01   East  Massachusetts   Cookies       Arrowroot        34
# 240 2025-08-08   East  Massachusetts   Cookies  Chocolate Chip       245
# 241 2025-08-15   East  Massachusetts  Crackers     Whole Wheat        30
# 242 2025-08-22   West          Texas      Bars            Bran        30
# 243 2025-08-29   West          Texas   Cookies  Oatmeal Raisin        44
#
#      Unit Price  Revenue
# 234         215     9030
# 235         482    48200
# 236         561    21318
# 237         426    10650
# 238         567    54432
# ...

# %%
sales.sample()
# Out:
#     Order Date Region          State Category    Product  Quantity  \
# 218 2025-03-07   East  Massachusetts  Cookies  Arrowroot        87
#
#      Unit Price  Revenue
# 218          30     2610

# %%
sales.sample(10)
# Out:
#     Order Date Region          State  Category         Product  Quantity  \
# 117 2023-03-31   West          Texas      Bars          Carrot        44
# 75  2022-06-10   West     California   Cookies  Chocolate Chip        70
# 90  2022-09-23   East  Massachusetts   Cookies       Arrowroot        81
# 97  2022-11-11   East       New York  Crackers     Whole Wheat        32
# 105 2023-01-06   West     California   Cookies       Arrowroot       103
# 143 2023-09-29   East       New York   Cookies  Oatmeal Raisin        97
# 175 2024-05-10   East  Massachusetts  Crackers     Whole Wheat        26
# 192 2024-09-06   West          Texas   Cookies  Chocolate Chip        64
# 242 2025-08-22   West          Texas      Bars            Bran        30
# 59  2022-02-18   East       New York      Bars            Bran       110
#
#      Unit Price  Revenue
# 117         244    10736
# 75          259    18130
# 90          233    18873
# 97          693    22176
# 105         574    59122
# ...

# %%
sales.columns
# Out:
# Index(['Order Date', 'Region', 'State', 'Category', 'Product', 'Quantity',
#        'Unit Price', 'Revenue'],
#       dtype='object')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order Date  244 non-null    datetime64[ns]
#  1   Region      244 non-null    object
#  2   State       244 non-null    object
#  3   Category    244 non-null    object
#  4   Product     244 non-null    object
#  5   Quantity    244 non-null    int64
#  6   Unit Price  244 non-null    int64
#  7   Revenue     244 non-null    int64
# dtypes: datetime64[ns](1), int64(3), object(4)
# memory usage: 15.4+ KB

# %%
sales.shape
# Out:
# (244, 8)

# %% [markdown]
# ## Describing Data
# It basically gives us the statics of the data mostly on the numericaal dataset

# %%
sales.describe()
# Out:
#          Quantity  Unit Price        Revenue
# count  244.000000  244.000000     244.000000
# mean    63.286885  373.983607   23865.987705
# std     47.112505  192.387811   22401.713204
# min     20.000000   30.000000    1400.000000
# 25%     31.000000  209.500000    8620.750000
# 50%     47.000000  373.500000   16929.000000
# 75%     80.000000  555.250000   30499.500000
# max    306.000000  697.000000  134521.000000

# %%
sales[['Quantity']]
# Out:
#      Quantity
# 0          33
# 1          87
# 2          58
# 3          82
# 4          38
# ..        ...
# 239        34
# 240       245
# 241        30
# 242        30
# 243        44
#
# [244 rows x 1 columns]

# %%
sales[['Region', 'State', 'Quantity', 'Revenue']].head(10)
# Out:
#   Region          State  Quantity  Revenue
# 0   East  Massachusetts        33    19668
# 1   East  Massachusetts        87    22185
# 2   West          Texas        58    21286
# 3   East       New York        82    55760
# 4   East  Massachusetts        38    12046
# 5   East  Massachusetts        54    30294
# 6   East  Massachusetts       149    17582
# 7   West          Texas        51    14229
# 8   East       New York       100    44900
# 9   East       New York        28    12684

# %%
sales.to_csv('sales.csv')

# %%
## Adding a new new column

sales['Total Revenue'] = sales['Quantity'] * sales['Unit Price']

# %%
sales.head(20)
# Out:
#    Order Date Region          State  Category         Product  Quantity  \
# 0  2021-01-01   East  Massachusetts      Bars          Carrot        33
# 1  2021-01-08   East  Massachusetts  Crackers     Whole Wheat        87
# 2  2021-01-15   West          Texas   Cookies  Chocolate Chip        58
# 3  2021-01-22   East       New York   Cookies  Chocolate Chip        82
# 4  2021-01-29   East  Massachusetts   Cookies       Arrowroot        38
# 5  2021-02-05   East  Massachusetts      Bars          Carrot        54
# 6  2021-02-12   East  Massachusetts  Crackers     Whole Wheat       149
# 7  2021-02-19   West          Texas      Bars          Carrot        51
# 8  2021-02-26   East       New York      Bars          Carrot       100
# 9  2021-03-05   East       New York    Snacks    Potato Chips        28
# 10 2021-03-12   East  Massachusetts   Cookies       Arrowroot        36
# 11 2021-03-19   East  Massachusetts   Cookies  Chocolate Chip        31
# ...

# %%
sales['CatPro'] = sales['Category'] + '_' + sales['Product']

# %%
sales.head(4)
# Out:
#   Order Date Region          State  Category         Product  Quantity  \
# 0 2021-01-01   East  Massachusetts      Bars          Carrot        33
# 1 2021-01-08   East  Massachusetts  Crackers     Whole Wheat        87
# 2 2021-01-15   West          Texas   Cookies  Chocolate Chip        58
# 3 2021-01-22   East       New York   Cookies  Chocolate Chip        82
#
#    Unit Price  Revenue  Total Revenue                  CatPro
# 0         596    19668          19668             Bars_Carrot
# 1         255    22185          22185    Crackers_Whole Wheat
# 2         367    21286          21286  Cookies_Chocolate Chip
# 3         680    55760          55760  Cookies_Chocolate Chip

# %% [markdown]
# # Deleting a column

# %%
sales
# Out:
#     Order Date Region          State  Category         Product  Quantity  \
# 0   2021-01-01   East  Massachusetts      Bars          Carrot        33
# 1   2021-01-08   East  Massachusetts  Crackers     Whole Wheat        87
# 2   2021-01-15   West          Texas   Cookies  Chocolate Chip        58
# 3   2021-01-22   East       New York   Cookies  Chocolate Chip        82
# 4   2021-01-29   East  Massachusetts   Cookies       Arrowroot        38
# ..         ...    ...            ...       ...             ...       ...
# 239 2025-08-01   East  Massachusetts   Cookies       Arrowroot        34
# 240 2025-08-08   East  Massachusetts   Cookies  Chocolate Chip       245
# 241 2025-08-15   East  Massachusetts  Crackers     Whole Wheat        30
# 242 2025-08-22   West          Texas      Bars            Bran        30
# 243 2025-08-29   West          Texas   Cookies  Oatmeal Raisin        44
#
#      Unit Price  Revenue  Total Revenue
# 0           596    19668          19668
# ...

# %%
sales.drop(['Total Revenue'], axis = 1, inplace=True)

# %%
sales
# Out:
#     Order Date Region          State  Category         Product  Quantity  \
# 0   2021-01-01   East  Massachusetts      Bars          Carrot        33
# 1   2021-01-08   East  Massachusetts  Crackers     Whole Wheat        87
# 2   2021-01-15   West          Texas   Cookies  Chocolate Chip        58
# 3   2021-01-22   East       New York   Cookies  Chocolate Chip        82
# 4   2021-01-29   East  Massachusetts   Cookies       Arrowroot        38
# ..         ...    ...            ...       ...             ...       ...
# 239 2025-08-01   East  Massachusetts   Cookies       Arrowroot        34
# 240 2025-08-08   East  Massachusetts   Cookies  Chocolate Chip       245
# 241 2025-08-15   East  Massachusetts  Crackers     Whole Wheat        30
# 242 2025-08-22   West          Texas      Bars            Bran        30
# 243 2025-08-29   West          Texas   Cookies  Oatmeal Raisin        44
#
#      Unit Price  Revenue
# 0           596    19668
# 1           255    22185
# ...
