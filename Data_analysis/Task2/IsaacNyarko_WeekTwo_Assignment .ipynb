# %% [markdown]
# ![Image.jpeg](attachment:Image.jpeg)

# %%
import pandas as pd

# %% [markdown]
# ## Loading the dataset into the notebook

# %%
prices = pd.read_csv('gas_prices.csv')

# %% [markdown]
# ## Displaying the first 8 rows of the gas_prices data set

# %%
prices.head(8)
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5  1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6  1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7  1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11
# 5         2.94  3.21  1.15
# 6         3.18  3.34  1.23
# 7         3.34  3.83  1.23

# %% [markdown]
# ## 2. Shape of the given data set

# %%
prices.shape
# Out:
# (19, 11)

# %% [markdown]
# ## 3. Different data types that can be found in the data set

# %%
prices.dtypes
# Out:
# Year             int64
# Australia      float64
# Canada         float64
# France         float64
# Germany        float64
# Italy          float64
# Japan          float64
# Mexico         float64
# South Korea    float64
# UK             float64
# USA            float64
# dtype: object

# %% [markdown]
# ### 4. Checking if there are missing data in the data set
#
# ### From the data set below, there is one missng value in Austrialia

# %%
prices.isna().sum()
# Out:
# Year           0
# Australia      1
# Canada         0
# France         0
# Germany        0
# Italy          0
# Japan          0
# Mexico         0
# South Korea    0
# UK             0
# USA            0
# dtype: int64

# %% [markdown]
# ### 5 Checking for duplicates
#
# ### From the output below it is observed that there are no duplicates

# %%
duplicates = prices.duplicated()

# %%
duplicates
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# dtype: bool

# %% [markdown]
# ### 6. Displaying data of any three countries

# %%
country = prices.loc[0:19,['Japan','Italy', 'UK']]

# %%
country
# Out:
#     Japan  Italy    UK
# 0    3.16   4.59  2.82
# 1    3.46   4.50  3.01
# 2    3.58   4.53  3.06
# 3    4.16   3.68  2.84
# 4    4.36   3.70  2.99
# 5    4.43   4.00  3.21
# 6    3.64   4.39  3.34
# 7    3.26   4.07  3.83
# 8    2.82   3.84  4.06
# 9    3.27   3.87  4.29
# 10   3.65   3.77  4.58
# 11   3.27   3.57  4.13
# 12   3.15   3.74  4.16
# 13   3.47   4.53  4.70
# 14   3.93   5.29  5.56
# 15   4.28   5.74  5.97
# 16   4.47   6.10  6.36
# 17   4.49   6.73  7.13
# 18   5.74   7.63  7.42

# %% [markdown]
# ### 7. Display of data with italy greater than or equal to 4

# %%
prices.loc[prices['Italy'] >= 4]
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 13  2003       2.19    1.99    4.35     4.59   4.53   3.47    2.04
# 14  2004       2.72    2.37    4.99     5.24   5.29   3.93    2.03
# 15  2005       3.23    2.89    5.46     5.66   5.74   4.28    2.22
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA
# 0          2.05  2.82  1.16
# 1          2.49  3.01  1.14
# ...

# %% [markdown]
# ### Display of data france data that is greater  than or equal to 5 and the year greater than or equal to 2000

# %%
prices[(prices['France'] >= 5) & (prices['Year'] >= 2000)]
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 15  2005       3.23    2.89    5.46     5.66   5.74   4.28    2.22
# 16  2006       3.54    3.26    5.88     6.03   6.10   4.47    2.31
# 17  2007       3.85    3.59    6.60     6.88   6.73   4.49    2.40
# 18  2008       4.45    4.08    7.51     7.75   7.63   5.74    2.45
#
#     South Korea    UK   USA
# 15         5.28  5.97  2.30
# 16         5.92  6.36  2.59
# 17         6.21  7.13  2.80
# 18         5.83  7.42  3.27
